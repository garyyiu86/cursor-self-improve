# %% [markdown]
# # Minimum QLoRA fine-tune (8GB VRAM target)
#
# Uses **Qwen2.5-1.5B-Instruct** in 4-bit + LoRA.
#
# **Needs:** NVIDIA GPU + CUDA PyTorch. Run the GPU check cell first.
#
# Install (once, in a venv):
# ```bash
# pip install -r requirements.txt
# ```
# Install CUDA PyTorch from https://pytorch.org if `torch.cuda.is_available()` is False.

# %%
import torch
print("PyTorch", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    p = torch.cuda.get_device_properties(0)
    print(p.name, f"{p.total_memory/1024**3:.1f} GB")
else:
    print("No NVIDIA CUDA GPU — this notebook cannot fine-tune locally.")

# %%
# Run the minimum trainer (same as train_min.py)
# %run train_min.py
